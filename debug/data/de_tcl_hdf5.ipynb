# %%
import time
import mediapy
import numpy as np
from tqdm import tqdm

from torch.utils.data import DataLoader

from robokit.datasets.tcl_datasets import TCLDatasetHDF5
from robokit.debug_utils import print_batch
from robokit.debug_utils import concatenate_rgb_images, plot_action_wrt_time, plot_force_sensor_wrt_time

# %% [markdown]
# ### Load TCLDatasetHDF5 and print a sample

# %%
dataset = TCLDatasetHDF5(
    root="/mnt/dongxu-fs1/data-hdd/geyuan/datasets/TCL/0209_tower_boby",
    h5_path="/mnt/dongxu-fs1/data-hdd/geyuan/datasets/TCL/hdf5/0209_tower_boby_240p.h5",
    use_extracted=False,
    load_keys=["rel_actions", "primary_rgb", "gripper_rgb", "robot_obs", "language_text", "force_torque"],
)
print("Total tasks:", len(dataset.tasks))
print_batch('TCLDatasetHDF5', dataset[0])
# Out:
# [TCLDataset] total length: 29192
# [TCLDatasetHDF5] using h5 data_manager: /mnt/dongxu-fs1/data-hdd/geyuan/datasets/TCL/hdf5/0209_tower_boby_240p.h5 . total_len: 29192
# Total tasks: 50
# TCLDatasetHDF5: Dict, keys=['rel_actions', 'primary_rgb', 'gripper_rgb', 'robot_obs', 'language_text', 'force_torque']
# --rel_actions, <class 'numpy.ndarray'>, shape=(7,), min=0.0000, max=0.0000, dtype=float64
# --primary_rgb, <class 'numpy.ndarray'>, shape=(240, 320, 3), min=0.0000, max=247.0000, dtype=uint8
# --gripper_rgb, <class 'numpy.ndarray'>, shape=(240, 320, 3), min=0.0000, max=230.0000, dtype=uint8
# --robot_obs, <class 'numpy.ndarray'>, shape=(14,), min=-0.0023, max=3.1431, dtype=float64
# --language_text: <class 'str'>, len=66, value='Pick up the purple disc from the pole and place it on the sponge.#'
# --force_torque, <class 'numpy.ndarray'>, shape=(6,), min=-0.0228, max=0.2532, dtype=float64

# %% [markdown]
# ### Dataloader speed test

# %%
train_loader = DataLoader(
    dataset,
    batch_size=64,
    shuffle=True,
    num_workers=8,
)

max_iter = 100
start_time = time.time()
for idx, batch in enumerate(tqdm(train_loader)):
    if idx == 0:
        print_batch('TCLDatasetHDF5 Dataloader', batch)
    if idx >= max_iter:
        break
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken for {max_iter} iterations: {elapsed_time:.2f} seconds, avg_speed={max_iter / elapsed_time:.2f} it/s")
# Out:
#   2%|█▉                                                                                                 | 9/457 [00:00<00:23, 19.15it/s]
# TCLDatasetHDF5 Dataloader: Dict, keys=['rel_actions', 'primary_rgb', 'gripper_rgb', 'robot_obs', 'language_text', 'force_torque']
# --rel_actions, <class 'torch.Tensor'>, shape=torch.Size([64, 7]), min=-0.9760, max=1.0000, dtype=torch.float64
# --primary_rgb, <class 'torch.Tensor'>, shape=torch.Size([64, 240, 320, 3]), min=0.0000, max=255.0000, dtype=torch.uint8
# --gripper_rgb, <class 'torch.Tensor'>, shape=torch.Size([64, 240, 320, 3]), min=0.0000, max=255.0000, dtype=torch.uint8
# --robot_obs, <class 'torch.Tensor'>, shape=torch.Size([64, 14]), min=-3.1416, max=4.4386, dtype=torch.float64
# --language_text: List, len=64, elem_type=<class 'str'>
# ----[0]: <class 'str'>, len=66, value='Pick up the purple disc from the pole and place it on the sponge.#'
# --force_torque, <class 'torch.Tensor'>, shape=torch.Size([64, 6]), min=-10.3800, max=5.1080, dtype=torch.float64
#  22%|█████████████████████▏                                                                           | 100/457 [00:03<00:11, 32.45it/s]
# Time taken for 100 iterations: 3.09 seconds, avg_speed=32.39 it/s
